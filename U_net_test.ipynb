# %% [markdown]
# # U-NET

# %%
import keras
import keras.backend as K
import numpy as np
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger, TensorBoard
import os
import pandas as pd
from sklearn.model_selection import KFold

from utils import get_score_from_all_slices
from model import create_xception_unet_n
from loss import  dice, dice_loss, get_loss
from data import create_train_date_generator, create_val_date_generator
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Activation, ReLU
from tensorflow.keras.layers import BatchNormalization, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model, Sequential

# %%
data_file_path = r"C:\Users\HP\Analysis-of-Anatomical-Tracings-of-Lesions-After-Stroke\data\train66.h5"
pretrained_weights_file = None
input_shape = (224, 192, 1)
batch_size = 8
num_folds = 5

# %%
def convolution_operation(entered_input, filters=64):
    # Taking first input and implementing the first conv block
    conv1 = Conv2D(filters, kernel_size = (3,3), padding = "same")(entered_input)
    batch_norm1 = BatchNormalization()(conv1)
    act1 = ReLU()(batch_norm1)
    
    # Taking first input and implementing the second conv block
    conv2 = Conv2D(filters, kernel_size = (3,3), padding = "same")(act1)
    batch_norm2 = BatchNormalization()(conv2)
    act2 = ReLU()(batch_norm2)
    
    return act2

def encoder(entered_input, filters=64):
    # Collect the start and end of each sub-block for normal pass and skip connections
    enc1 = convolution_operation(entered_input, filters)
    MaxPool1 = MaxPooling2D(strides = (2,2))(enc1)
    return enc1, MaxPool1

def decoder(entered_input, skip, filters=64):
    # Upsampling and concatenating the essential features
    Upsample = Conv2DTranspose(filters, (2, 2), strides=2, padding="same")(entered_input)
    Connect_Skip = Concatenate()([Upsample, skip])
    out = convolution_operation(Connect_Skip, filters)
    return out

def U_Net(Image_Size):
    # Take the image size and shape
    input1 = Input(Image_Size)
    
    # Construct the encoder blocks
    skip1, encoder_1 = encoder(input1, 64)
    skip2, encoder_2 = encoder(encoder_1, 64*2)
    skip3, encoder_3 = encoder(encoder_2, 64*4)
    skip4, encoder_4 = encoder(encoder_3, 64*8)
    
    # Preparing the next block
    conv_block = convolution_operation(encoder_4, 64*16)
    
    # Construct the decoder blocks
    decoder_1 = decoder(conv_block, skip4, 64*8)
    decoder_2 = decoder(decoder_1, skip3, 64*4)
    decoder_3 = decoder(decoder_2, skip2, 64*2)
    decoder_4 = decoder(decoder_3, skip1, 64)
    
    out = Conv2D(1, 1, padding="same", activation="sigmoid")(decoder_4)

    model = Model(input1, out)
    return model

# %%
def train(fold, train_patient_indexes, val_patient_indexes):

    log_dir = 'fold_' + str(fold) + '/'
    if not os.path.isdir(log_dir):
        os.mkdir(log_dir)
    num_slices_train = len(train_patient_indexes) * 189
    num_slices_val = len(val_patient_indexes) * 189

    # Create model
    K.clear_session()
    model.compile(optimizer=Adam(learning_rate=1e-3), loss=get_loss, metrics=[dice])

    # Get callbacks
    #checkpoint = ModelCheckpoint(log_dir + 'ep={epoch:03d}-loss={loss:.3f}-val_loss={val_loss:.3f}.h5', verbose=1,
    #                             monitor='val_loss', save_weights_only=True, save_best_only=True, save_freq=1)
    checkpoint = ModelCheckpoint(log_dir + 'ep={epoch:03d}-loss={loss:.3f}.h5', verbose=1,
                                 monitor='loss', save_weights_only=True, save_best_only=True, save_freq=1)

    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, min_delta=1e-3, patience=3, verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1)
    csv_logger = CSVLogger(log_dir + 'record.csv')
    tensorboard = TensorBoard(log_dir=log_dir)

    # train the model
    model.fit(
        create_train_date_generator(patient_indexes=train_patient_indexes, h5_file_path=data_file_path, batch_size=batch_size),
        steps_per_epoch=max(1, num_slices_train // batch_size),
        validation_data=create_val_date_generator(patient_indexes=val_patient_indexes, h5_file_path=data_file_path, batch_size=9),
        validation_steps=max(1, num_slices_val // 9),
        epochs=1,    #100
        initial_epoch=0,
        callbacks=[checkpoint, reduce_lr, early_stopping, tensorboard, csv_logger])
    model.save_weights(log_dir + 'trained_final_weights.h5')

    # Evaluate model
    predicts = []
    labels = []
    f = create_val_date_generator(patient_indexes=val_patient_indexes, h5_file_path=data_file_path)
    for _ in range(num_slices_val):
        img, label = f.__next__()
        predicts.append(model.predict(img))
        labels.append(label)
    predicts = np.array(predicts)
    labels = np.array(labels)
    score_record = get_score_from_all_slices(labels=labels, predicts=predicts)

    # save score
    df = pd.DataFrame(score_record)
    df.to_csv(os.path.join(log_dir, 'score_record.csv'), index=False)

    # print score
    mean_score = {}
    for key in score_record.keys():
        print('In fold ', fold, ', average', key, ' value is: \t ', np.mean(score_record[key]))
        mean_score[key] = np.mean(score_record[key])

    # exit training
    K.clear_session()
    return mean_score

# %%
def main():
    # prepare indexes of patients for training and validation, respectively
    num_patients = 66  #229
    patients_indexes = np.array([i for i in range(num_patients)])
    kf = KFold(n_splits=num_folds, shuffle=False)

    # train, and record the scores of each fold
    folds_score = []
    for fold, (train_patient_indexes, val_patient_indexes) in enumerate(kf.split(patients_indexes)):
        fold_mean_score = train(fold=fold, train_patient_indexes=train_patient_indexes, val_patient_indexes=val_patient_indexes)
        folds_score.append(fold_mean_score)

    # calculate average score
    print('Final score from ', num_folds, ' folds cross validation:')
    final_score = {}
    for key in folds_score[0].keys():
        scores = []
        for i in range(num_folds):
            scores.append(folds_score[i][key])
        final_score[key] = np.mean(scores)
        print(key, ' score: \t', final_score[key])

    # save final score
    df = pd.DataFrame(final_score, index=[0])
    df.to_csv('u_net_final_score.csv', index=False)

# %%
if __name__ == "__main__":
    import os
    os.environ['CUDA_VISIBLE_DEVICES'] = '1'
    input_shape = (224, 192, 1)
    model = U_Net(input_shape)
    model.summary()
    os.environ['CUDA_VISIBLE_DEVICES'] = '1'
    main()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 192, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 192, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 192, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 224, 192, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 192, 64  36928       ['re_lu[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 224, 192, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  re_lu_1 (ReLU)                 (None, 224, 192, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 96, 64)  0           ['re_lu_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 112, 96, 128  73856       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 112, 96, 128  512        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  re_lu_2 (ReLU)                 (None, 112, 96, 128  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 112, 96, 128  147584      ['re_lu_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 112, 96, 128  512        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  re_lu_3 (ReLU)                 (None, 112, 96, 128  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 48, 128)  0          ['re_lu_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 48, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 48, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 56, 48, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 48, 256)  590080      ['re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 48, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 56, 48, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 24, 256)  0          ['re_lu_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 24, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 24, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 28, 24, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 24, 512)  2359808     ['re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 28, 24, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 28, 24, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 12, 512)  0          ['re_lu_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 12, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 14, 12, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  re_lu_8 (ReLU)                 (None, 14, 12, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 14, 12, 1024  9438208     ['re_lu_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 14, 12, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  re_lu_9 (ReLU)                 (None, 14, 12, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 28, 24, 512)  2097664    ['re_lu_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 28, 24, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 're_lu_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 24, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 24, 512)  2359808     ['re_lu_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 56, 48, 256)  524544     ['re_lu_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 56, 48, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   're_lu_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 48, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 56, 48, 256)  590080      ['re_lu_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 112, 96, 128  131200     ['re_lu_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 112, 96, 256  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 're_lu_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 112, 96, 128  295040      ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 112, 96, 128  512        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  re_lu_14 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 112, 96, 128  147584      ['re_lu_14[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 112, 96, 128  512        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  re_lu_15 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 224, 192, 64  32832      ['re_lu_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 224, 192, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                're_lu_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 224, 192, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 224, 192, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  re_lu_16 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 224, 192, 64  36928       ['re_lu_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 224, 192, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  re_lu_17 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 224, 192, 1)  65          ['re_lu_17[0][0]']
#
# ==================================================================================================
# Total params: 31,054,145
# Trainable params: 31,042,369
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 8
#       6 model.summary()
#       7 os.environ['CUDA_VISIBLE_DEVICES'] = '1'
# ----> 8 main()
#
# Cell In[5], line 10, in main()
#       8 folds_score = []
#       9 for fold, (train_patient_indexes, val_patient_indexes) in enumerate(kf.split(patients_indexes)):
# ---> 10     fold_mean_score = train(fold=fold, train_patient_indexes=train_patient_indexes, val_patient_indexes=val_patient_indexes)
#      11     folds_score.append(fold_mean_score)
#      13 # calculate average score
#
# Cell In[4], line 25, in train(fold, train_patient_indexes, val_patient_indexes)
#      22 tensorboard = TensorBoard(log_dir=log_dir)
#      24 # train the model
# ---> 25 model.fit(
#      26     create_train_date_generator(patient_indexes=train_patient_indexes, h5_file_path=data_file_path, batch_size=batch_size),
#      27     steps_per_epoch=max(1, num_slices_train // batch_size),
#      28     validation_data=create_val_date_generator(patient_indexes=val_patient_indexes, h5_file_path=data_file_path, batch_size=9),
#      29     validation_steps=max(1, num_slices_val // 9),
#      30     epochs=1,    #100
#      31     initial_epoch=0,
#      32     callbacks=[checkpoint, reduce_lr, early_stopping, tensorboard, csv_logger])
#      33 model.save_weights(log_dir + 'trained_final_weights.h5')
#      35 # Evaluate model
#
# File d:\ExtInstallations\OtherApps\Anaconda\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File d:\Projects\Sem4\SLP\data.py:13, in train_data_generator(patient_indexes, h5_file_path, batch_size)
#      11 def train_data_generator(patient_indexes, h5_file_path, batch_size):
#      12     i = 0
# ---> 13     file = h5py.File(h5_file_path, 'r')
#      14     imgs = file['data']
#      15     labels = file['label']
#
# File d:\ExtInstallations\OtherApps\Anaconda\lib\site-packages\h5py\_hl\files.py:533, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, **kwds)
#     525     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     526                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     527                      alignment_threshold=alignment_threshold,
#     528                      alignment_interval=alignment_interval,
#     529                      **kwds)
#     530     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     531                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     532                      fs_page_size=fs_page_size)
# --> 533     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     535 if isinstance(libver, tuple):
#     536     self._libver = libver
#
# File d:\ExtInstallations\OtherApps\Anaconda\lib\site-packages\h5py\_hl\files.py:226, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     224     if swmr and swmr_support:
#     225         flags |= h5f.ACC_SWMR_READ
# --> 226     fid = h5f.open(name, flags, fapl=fapl)
#     227 elif mode == 'r+':
#     228     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\h5f.pyx:106, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = 'C:\Users\HP\Analysis-of-Anatomical-Tracings-of-Lesions-After-Stroke\data\train66.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
