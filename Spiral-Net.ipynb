# %% [markdown]
# # SPIRAL-NET

# %%
import keras
import keras.backend as K
import numpy as np
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger, TensorBoard
import os
import pandas as pd
from sklearn.model_selection import KFold

from utils import get_score_from_all_slices
from model import create_xception_unet_n
from loss import  dice, dice_loss, get_loss
from data import create_train_date_generator, create_val_date_generator
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Activation, ReLU
from tensorflow.keras.layers import BatchNormalization, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model, Sequential

# %%
data_file_path = r"D:\Projects\Sem4\SLP\Data\ATLAS_R2.0\ATLAS_2\train66.h5"
pretrained_weights_file = None
input_shape = (224, 192, 1)
batch_size = 8
num_folds = 5

# %%
from unittest import skip


def convolution_operation(entered_input, filters=64):
    # Taking first input and implementing the first conv block
    conv1 = Conv2D(filters, kernel_size = (3,3), padding = "same")(entered_input)
    batch_norm1 = BatchNormalization()(conv1)
    act1 = ReLU()(batch_norm1)
    
    # Taking first input and implementing the second conv block
    conv2 = Conv2D(filters, kernel_size = (3,3), padding = "same")(act1)
    batch_norm2 = BatchNormalization()(conv2)
    act2 = ReLU()(batch_norm2)
    
    return act2

def encoder(entered_input, filters=64):
    # Collect the start and end of each sub-block for normal pass and skip connections
    enc1 = convolution_operation(entered_input, filters)
    MaxPool1 = MaxPooling2D(strides = (2,2))(enc1)
    return enc1, MaxPool1

def decoder(entered_input, skip, filters=64):
    # Upsampling and concatenating the essential features
    Upsample = Conv2DTranspose(filters, (2, 2), strides=2, padding="same")(entered_input)
    Connect_Skip = Concatenate()([Upsample, skip])
    out = convolution_operation(Connect_Skip, filters)
    return out

def U_Net_Base(input1, skip = []):
    # Take the image size and shape

    # Construct the encoder blocks
    skip1, encoder_1 = encoder(input1, 64)
    skip2, encoder_2 = encoder(encoder_1, 64*2)
    skip3, encoder_3 = encoder(encoder_2, 64*4)
    
    # Preparing the next block
    conv_block = convolution_operation(encoder_3, 64*8)
    
    # Construct the decoder blocks
    decoder_1 = decoder(conv_block, skip3, 64*4)
    decoder_2 = decoder(decoder_1, skip2, 64*2)
    decoder_3 = decoder(decoder_2, skip1, 64)
    
    if len(skip) == 0:
        return decoder_3, [skip1,skip2,skip3]
    else:
        return decoder_3, skip

def Spiral_Net(Image_Size, num_units = 3):
    input1 = Input(Image_Size)
    input2 = None
    skip = []
    for _ in range(num_units):
        if input2 is None:
            input2, skip = U_Net_Base(input1)
        else:
            input2, skip= U_Net_Base(input2, skip)

    out = Conv2D(1, 1, padding="same", activation="sigmoid")(input2)
    model = Model(input1, out)
    return model

# %%
def train(fold, train_patient_indexes, val_patient_indexes):

    log_dir = 'fold_' + str(fold) + '/'
    if not os.path.isdir(log_dir):
        os.mkdir(log_dir)
    num_slices_train = len(train_patient_indexes) * 189
    num_slices_val = len(val_patient_indexes) * 189

    # Create model
    K.clear_session()
    model.compile(optimizer=Adam(learning_rate=1e-3), loss=get_loss, metrics=[dice])

    # Get callbacks
    #checkpoint = ModelCheckpoint(log_dir + 'ep={epoch:03d}-loss={loss:.3f}-val_loss={val_loss:.3f}.h5', verbose=1,
    #                             monitor='val_loss', save_weights_only=True, save_best_only=True, save_freq=1)
    checkpoint = ModelCheckpoint(log_dir + 'ep={epoch:03d}-loss={loss:.3f}.h5', verbose=1,
                                 monitor='loss', save_weights_only=True, save_best_only=True, save_freq=1)

    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, min_delta=1e-3, patience=3, verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1)
    csv_logger = CSVLogger(log_dir + 'record.csv')
    tensorboard = TensorBoard(log_dir=log_dir)

    # train the model
    model.fit(
        create_train_date_generator(patient_indexes=train_patient_indexes, h5_file_path=data_file_path, batch_size=batch_size),
        steps_per_epoch=max(1, num_slices_train // batch_size),
        validation_data=create_val_date_generator(patient_indexes=val_patient_indexes, h5_file_path=data_file_path, batch_size=9),
        validation_steps=max(1, num_slices_val // 9),
        epochs=1,    #100
        initial_epoch=0,
        callbacks=[checkpoint, reduce_lr, early_stopping, tensorboard, csv_logger])
    model.save_weights(log_dir + 'trained_final_weights.h5')

    # Evaluate model
    predicts = []
    labels = []
    f = create_val_date_generator(patient_indexes=val_patient_indexes, h5_file_path=data_file_path)
    for _ in range(num_slices_val):
        img, label = f.__next__()
        predicts.append(model.predict(img))
        labels.append(label)
    predicts = np.array(predicts)
    labels = np.array(labels)
    score_record = get_score_from_all_slices(labels=labels, predicts=predicts)

    # save score
    df = pd.DataFrame(score_record)
    df.to_csv(os.path.join(log_dir, 'score_record.csv'), index=False)

    # print score
    mean_score = {}
    for key in score_record.keys():
        print('In fold ', fold, ', average', key, ' value is: \t ', np.mean(score_record[key]))
        mean_score[key] = np.mean(score_record[key])

    # exit training
    K.clear_session()
    return mean_score

# %%
def main():
    # prepare indexes of patients for training and validation, respectively
    num_patients = 66  #229
    patients_indexes = np.array([i for i in range(num_patients)])
    kf = KFold(n_splits=num_folds, shuffle=False)

    # train, and record the scores of each fold
    folds_score = []
    for fold, (train_patient_indexes, val_patient_indexes) in enumerate(kf.split(patients_indexes)):
        fold_mean_score = train(fold=fold, train_patient_indexes=train_patient_indexes, val_patient_indexes=val_patient_indexes)
        folds_score.append(fold_mean_score)

    # calculate average score
    print('Final score from ', num_folds, ' folds cross validation:')
    final_score = {}
    for key in folds_score[0].keys():
        scores = []
        for i in range(num_folds):
            scores.append(folds_score[i][key])
        final_score[key] = np.mean(scores)
        print(key, ' score: \t', final_score[key])

    # save final score
    df = pd.DataFrame(final_score, index=[0])
    df.to_csv('u_net_final_score.csv', index=False)

# %%
if __name__ == "__main__":
    import os
    os.environ['CUDA_VISIBLE_DEVICES'] = '1'
    input_shape = (224, 192, 1)
    model = Spiral_Net(input_shape)
    model.summary()
    os.environ['CUDA_VISIBLE_DEVICES'] = '1'
    main()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 192, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 192, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 192, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 224, 192, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 192, 64  36928       ['re_lu[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 224, 192, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  re_lu_1 (ReLU)                 (None, 224, 192, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 96, 64)  0           ['re_lu_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 112, 96, 128  73856       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 112, 96, 128  512        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  re_lu_2 (ReLU)                 (None, 112, 96, 128  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 112, 96, 128  147584      ['re_lu_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 112, 96, 128  512        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  re_lu_3 (ReLU)                 (None, 112, 96, 128  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 48, 128)  0          ['re_lu_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 48, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 48, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 56, 48, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 48, 256)  590080      ['re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 48, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 56, 48, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 24, 256)  0          ['re_lu_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 24, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 24, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 28, 24, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 24, 512)  2359808     ['re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 28, 24, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 28, 24, 512)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 56, 48, 256)  524544     ['re_lu_7[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 56, 48, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   're_lu_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 48, 256)  1179904     ['concatenate[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 56, 48, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 56, 48, 256)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 56, 48, 256)  590080      ['re_lu_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 56, 48, 256)  1024       ['conv2d_9[0][0]']
#  rmalization)
#
#  re_lu_9 (ReLU)                 (None, 56, 48, 256)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 112, 96, 128  131200     ['re_lu_9[0][0]']
#  spose)                         )
#
#  concatenate_1 (Concatenate)    (None, 112, 96, 256  0           ['conv2d_transpose_1[0][0]',
#                                 )                                 're_lu_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 112, 96, 128  295040      ['concatenate_1[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 112, 96, 128  512        ['conv2d_10[0][0]']
#  ormalization)                  )
#
#  re_lu_10 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 112, 96, 128  147584      ['re_lu_10[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 112, 96, 128  512        ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  re_lu_11 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_transpose_2 (Conv2DTran  (None, 224, 192, 64  32832      ['re_lu_11[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 224, 192, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                're_lu_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 224, 192, 64  73792       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 224, 192, 64  256        ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  re_lu_12 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 224, 192, 64  36928       ['re_lu_12[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 224, 192, 64  256        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  re_lu_13 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 224, 192, 64  36928       ['re_lu_13[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 224, 192, 64  256        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  re_lu_14 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 224, 192, 64  36928       ['re_lu_14[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 224, 192, 64  256        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  re_lu_15 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 112, 96, 64)  0          ['re_lu_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 112, 96, 128  73856       ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 112, 96, 128  512        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  re_lu_16 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 112, 96, 128  147584      ['re_lu_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 112, 96, 128  512        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  re_lu_17 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 56, 48, 128)  0          ['re_lu_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 56, 48, 256)  295168      ['max_pooling2d_4[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 56, 48, 256)  590080      ['re_lu_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_19[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 28, 24, 256)  0          ['re_lu_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 24, 512)  1180160     ['max_pooling2d_5[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_20[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 28, 24, 512)  2359808     ['re_lu_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_21[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 56, 48, 256)  524544     ['re_lu_21[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 56, 48, 512)  0           ['conv2d_transpose_3[0][0]',
#                                                                   're_lu_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 56, 48, 256)  1179904     ['concatenate_3[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  re_lu_22 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 56, 48, 256)  590080      ['re_lu_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 112, 96, 128  131200     ['re_lu_23[0][0]']
#  spose)                         )
#
#  concatenate_4 (Concatenate)    (None, 112, 96, 256  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 're_lu_17[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 112, 96, 128  295040      ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 112, 96, 128  512        ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  re_lu_24 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_24[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 112, 96, 128  147584      ['re_lu_24[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 112, 96, 128  512        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  re_lu_25 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  conv2d_transpose_5 (Conv2DTran  (None, 224, 192, 64  32832      ['re_lu_25[0][0]']
#  spose)                         )
#
#  concatenate_5 (Concatenate)    (None, 224, 192, 12  0           ['conv2d_transpose_5[0][0]',
#                                 8)                                're_lu_15[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 224, 192, 64  73792       ['concatenate_5[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 224, 192, 64  256        ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  re_lu_26 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 224, 192, 64  36928       ['re_lu_26[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 224, 192, 64  256        ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  re_lu_27 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 224, 192, 64  36928       ['re_lu_27[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 224, 192, 64  256        ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  re_lu_28 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 224, 192, 64  36928       ['re_lu_28[0][0]']
#                                 )
#
#  batch_normalization_29 (BatchN  (None, 224, 192, 64  256        ['conv2d_29[0][0]']
#  ormalization)                  )
#
#  re_lu_29 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_29[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 112, 96, 64)  0          ['re_lu_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 112, 96, 128  73856       ['max_pooling2d_6[0][0]']
#                                 )
#
#  batch_normalization_30 (BatchN  (None, 112, 96, 128  512        ['conv2d_30[0][0]']
#  ormalization)                  )
#
#  re_lu_30 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_30[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 112, 96, 128  147584      ['re_lu_30[0][0]']
#                                 )
#
#  batch_normalization_31 (BatchN  (None, 112, 96, 128  512        ['conv2d_31[0][0]']
#  ormalization)                  )
#
#  re_lu_31 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_31[0][0]']
#                                 )
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 56, 48, 128)  0          ['re_lu_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 56, 48, 256)  295168      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 56, 48, 256)  590080      ['re_lu_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_33[0][0]']
#  ormalization)
#
#  re_lu_33 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_33[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 28, 24, 256)  0          ['re_lu_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 28, 24, 512)  1180160     ['max_pooling2d_8[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_34[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 28, 24, 512)  2359808     ['re_lu_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_35[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 56, 48, 256)  524544     ['re_lu_35[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 56, 48, 512)  0           ['conv2d_transpose_6[0][0]',
#                                                                   're_lu_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 56, 48, 256)  1179904     ['concatenate_6[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_36[0][0]']
#  ormalization)
#
#  re_lu_36 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 56, 48, 256)  590080      ['re_lu_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_37[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 112, 96, 128  131200     ['re_lu_37[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 112, 96, 256  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 're_lu_31[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 112, 96, 128  295040      ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 112, 96, 128  512        ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  re_lu_38 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_38[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 112, 96, 128  147584      ['re_lu_38[0][0]']
#                                 )
#
#  batch_normalization_39 (BatchN  (None, 112, 96, 128  512        ['conv2d_39[0][0]']
#  ormalization)                  )
#
#  re_lu_39 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_39[0][0]']
#                                 )
#
#  conv2d_transpose_8 (Conv2DTran  (None, 224, 192, 64  32832      ['re_lu_39[0][0]']
#  spose)                         )
#
#  concatenate_8 (Concatenate)    (None, 224, 192, 12  0           ['conv2d_transpose_8[0][0]',
#                                 8)                                're_lu_29[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 224, 192, 64  73792       ['concatenate_8[0][0]']
#                                 )
#
#  batch_normalization_40 (BatchN  (None, 224, 192, 64  256        ['conv2d_40[0][0]']
#  ormalization)                  )
#
#  re_lu_40 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_40[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 224, 192, 64  36928       ['re_lu_40[0][0]']
#                                 )
#
#  batch_normalization_41 (BatchN  (None, 224, 192, 64  256        ['conv2d_41[0][0]']
#  ormalization)                  )
#
#  re_lu_41 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_41[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 224, 192, 1)  65          ['re_lu_41[0][0]']
#
# ==================================================================================================
# Total params: 23,194,817
# Trainable params: 23,177,921
# Non-trainable params: 16,896
# __________________________________________________________________________________________________
# 9828
#
# Epoch 1: loss improved from inf to 1.63074, saving model to fold_0\ep=001-loss=1.631.h5
#    1/1228 [..............................] - ETA: 41:06:50 - loss: 1.6307 - dice: 0.0094
# Epoch 1: loss improved from 1.63074 to 1.62786, saving model to fold_0\ep=001-loss=1.628.h5
#    2/1228 [..............................] - ETA: 564:56:09 - loss: 1.6279 - dice: 0.0048
