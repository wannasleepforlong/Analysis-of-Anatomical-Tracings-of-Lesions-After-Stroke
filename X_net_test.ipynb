# %%
import keras
import keras.backend as K
import numpy as np
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger, TensorBoard
import os
import pandas as pd
from sklearn.model_selection import KFold

from utils import get_score_from_all_slices
from model import create_xception_unet_n
from loss import  dice, dice_loss, get_loss
from data import create_train_date_generator, create_val_date_generator
# Out:
# Yay

# %%
#data_file_path = '/data/data/ATLAS_h5/ATLAS.h5'
data_file_path = r"C:\Users\HP\X-Net\data\train66.h5"
pretrained_weights_file = None
input_shape = (224, 192, 1)
batch_size = 8
num_folds = 5


def train(fold, train_patient_indexes, val_patient_indexes):

    log_dir = 'fold_' + str(fold) + '/'
    if not os.path.isdir(log_dir):
        os.mkdir(log_dir)
    num_slices_train = len(train_patient_indexes) * 189
    num_slices_val = len(val_patient_indexes) * 189

    # Create model
    K.clear_session()
    model = create_xception_unet_n(input_shape=input_shape, pretrained_weights_file=pretrained_weights_file)
    model.compile(optimizer=Adam(learning_rate=1e-3), loss=get_loss, metrics=[dice])

    # Get callbacks
    #checkpoint = ModelCheckpoint(log_dir + 'ep={epoch:03d}-loss={loss:.3f}-val_loss={val_loss:.3f}.h5', verbose=1,
    #                             monitor='val_loss', save_weights_only=True, save_best_only=True, save_freq=1)
    checkpoint = ModelCheckpoint(log_dir + 'ep={epoch:03d}-loss={loss:.3f}.h5', verbose=1,
                             monitor='loss', save_weights_only=True, save_best_only=True, save_freq=1)

    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, min_delta=1e-3, patience=3, verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1)
    csv_logger = CSVLogger(log_dir + 'record.csv')
    tensorboard = TensorBoard(log_dir=log_dir)

    # train the model
    model.fit(
        create_train_date_generator(patient_indexes=train_patient_indexes, h5_file_path=data_file_path, batch_size=batch_size),
        steps_per_epoch=max(1, num_slices_train // batch_size),
        validation_data=create_val_date_generator(patient_indexes=val_patient_indexes, h5_file_path=data_file_path, batch_size=9),
        validation_steps=max(1, num_slices_val // 9),
        epochs=1,    #100
        initial_epoch=0,
        callbacks=[checkpoint, reduce_lr, early_stopping, tensorboard, csv_logger])
    model.save_weights(log_dir + 'trained_final_weights.h5')

    # Evaluate model
    predicts = []
    labels = []
    f = create_val_date_generator(patient_indexes=val_patient_indexes, h5_file_path=data_file_path)
    for _ in range(num_slices_val):
        img, label = f.__next__()
        predicts.append(model.predict(img))
        labels.append(label)
    predicts = np.array(predicts)
    labels = np.array(labels)
    score_record = get_score_from_all_slices(labels=labels, predicts=predicts)

    # save score
    df = pd.DataFrame(score_record)
    df.to_csv(os.path.join(log_dir, 'score_record.csv'), index=False)

    # print score
    mean_score = {}
    for key in score_record.keys():
        print('In fold ', fold, ', average', key, ' value is: \t ', np.mean(score_record[key]))
        mean_score[key] = np.mean(score_record[key])

    # exit training
    K.clear_session()
    return mean_score


def main():
    # prepare indexes of patients for training and validation, respectively
    num_patients = 66  #229
    patients_indexes = np.array([i for i in range(num_patients)])
    kf = KFold(n_splits=num_folds, shuffle=False)

    # train, and record the scores of each fold
    folds_score = []
    for fold, (train_patient_indexes, val_patient_indexes) in enumerate(kf.split(patients_indexes)):
        fold_mean_score = train(fold=fold, train_patient_indexes=train_patient_indexes, val_patient_indexes=val_patient_indexes)
        folds_score.append(fold_mean_score)

    # calculate average score
    print('Final score from ', num_folds, ' folds cross validation:')
    final_score = {}
    for key in folds_score[0].keys():
        scores = []
        for i in range(num_folds):
            scores.append(folds_score[i][key])
        final_score[key] = np.mean(scores)
        print(key, ' score: \t', final_score[key])

    # save final score
    df = pd.DataFrame(final_score, index=[0])
    df.to_csv('x_net_final_score.csv', index=False)
# Out:
# Yay

# %%
if __name__ == '__main__':
    os.environ['CUDA_VISIBLE_DEVICES'] = '1'
    main()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 14, 12, 1024), dtype=tf.float32, name=None), name='re_lu_36/Relu:0', description="created by layer 're_lu_36'")
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 192, 1  0           []
#                                 )]
#
#  depthwise_conv2d (DepthwiseCon  (None, 224, 192, 1)  9          ['input_1[0][0]']
#  v2D)
#
#  batch_normalization_1 (BatchNo  (None, 224, 192, 1)  4          ['depthwise_conv2d[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 224, 192, 1)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 224, 192, 64  128         ['re_lu_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 224, 192, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  re_lu_2 (ReLU)                 (None, 224, 192, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 224, 192, 64  576        ['re_lu_2[0][0]']
#  onv2D)                         )
#
#  batch_normalization_3 (BatchNo  (None, 224, 192, 64  256        ['depthwise_conv2d_1[0][0]']
#  rmalization)                   )
#
#  re_lu_3 (ReLU)                 (None, 224, 192, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 224, 192, 64  4160        ['re_lu_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 224, 192, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  re_lu_4 (ReLU)                 (None, 224, 192, 64  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 224, 192, 64  576        ['re_lu_4[0][0]']
#  onv2D)                         )
#
#  batch_normalization_5 (BatchNo  (None, 224, 192, 64  256        ['depthwise_conv2d_2[0][0]']
#  rmalization)                   )
#
#  re_lu_5 (ReLU)                 (None, 224, 192, 64  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 224, 192, 64  4160        ['re_lu_5[0][0]']
#                                 )
#
#  conv2d (Conv2D)                (None, 224, 192, 64  128         ['input_1[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 224, 192, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  batch_normalization (BatchNorm  (None, 224, 192, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu_6 (ReLU)                 (None, 224, 192, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  re_lu (ReLU)                   (None, 224, 192, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  add (Add)                      (None, 224, 192, 64  0           ['re_lu_6[0][0]',
#                                 )                                 're_lu[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 96, 64)  0           ['add[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 112, 96, 64)  576        ['max_pooling2d[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 112, 96, 64)  256        ['depthwise_conv2d_3[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 112, 96, 64)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 112, 96, 128  8320        ['re_lu_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 112, 96, 128  512        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  re_lu_9 (ReLU)                 (None, 112, 96, 128  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 112, 96, 128  1152       ['re_lu_9[0][0]']
#  onv2D)                         )
#
#  batch_normalization_10 (BatchN  (None, 112, 96, 128  512        ['depthwise_conv2d_4[0][0]']
#  ormalization)                  )
#
#  re_lu_10 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 112, 96, 128  16512       ['re_lu_10[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 112, 96, 128  512        ['conv2d_6[0][0]']
#  ormalization)                  )
#
#  re_lu_11 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 112, 96, 128  1152       ['re_lu_11[0][0]']
#  onv2D)                         )
#
#  batch_normalization_12 (BatchN  (None, 112, 96, 128  512        ['depthwise_conv2d_5[0][0]']
#  ormalization)                  )
#
#  re_lu_12 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 112, 96, 128  16512       ['re_lu_12[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 112, 96, 128  8320        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 112, 96, 128  512        ['conv2d_7[0][0]']
#  ormalization)                  )
#
#  batch_normalization_7 (BatchNo  (None, 112, 96, 128  512        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  re_lu_13 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  re_lu_7 (ReLU)                 (None, 112, 96, 128  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 112, 96, 128  0           ['re_lu_13[0][0]',
#                                 )                                 're_lu_7[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 48, 128)  0          ['add_1[0][0]']
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 56, 48, 128)  1152       ['max_pooling2d_1[0][0]']
#  onv2D)
#
#  batch_normalization_15 (BatchN  (None, 56, 48, 128)  512        ['depthwise_conv2d_6[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 56, 48, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 56, 48, 256)  33024       ['re_lu_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_9[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_16[0][0]']
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 56, 48, 256)  2304       ['re_lu_16[0][0]']
#  onv2D)
#
#  batch_normalization_17 (BatchN  (None, 56, 48, 256)  1024       ['depthwise_conv2d_7[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 48, 256)  65792       ['re_lu_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_10[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_18[0][0]']
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 56, 48, 256)  2304       ['re_lu_18[0][0]']
#  onv2D)
#
#  batch_normalization_19 (BatchN  (None, 56, 48, 256)  1024       ['depthwise_conv2d_8[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 56, 48, 256)  65792       ['re_lu_19[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 48, 256)  33024       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_8[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_20[0][0]']
#
#  re_lu_14 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_14[0][0]']
#
#  add_2 (Add)                    (None, 56, 48, 256)  0           ['re_lu_20[0][0]',
#                                                                   're_lu_14[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 24, 256)  0          ['add_2[0][0]']
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 28, 24, 256)  2304       ['max_pooling2d_2[0][0]']
#  onv2D)
#
#  batch_normalization_22 (BatchN  (None, 28, 24, 256)  1024       ['depthwise_conv2d_9[0][0]']
#  ormalization)
#
#  re_lu_22 (ReLU)                (None, 28, 24, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 24, 512)  131584      ['re_lu_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_23[0][0]']
#
#  depthwise_conv2d_10 (Depthwise  (None, 28, 24, 512)  4608       ['re_lu_23[0][0]']
#  Conv2D)
#
#  batch_normalization_24 (BatchN  (None, 28, 24, 512)  2048       ['depthwise_conv2d_10[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 24, 512)  262656      ['re_lu_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_14[0][0]']
#  ormalization)
#
#  re_lu_25 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_25[0][0]']
#
#  depthwise_conv2d_11 (Depthwise  (None, 28, 24, 512)  4608       ['re_lu_25[0][0]']
#  Conv2D)
#
#  batch_normalization_26 (BatchN  (None, 28, 24, 512)  2048       ['depthwise_conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 24, 512)  262656      ['re_lu_26[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 24, 512)  131584      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_12[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_27[0][0]']
#
#  re_lu_21 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_21[0][0]']
#
#  add_3 (Add)                    (None, 28, 24, 512)  0           ['re_lu_27[0][0]',
#                                                                   're_lu_21[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 12, 512)  0          ['add_3[0][0]']
#
#  depthwise_conv2d_12 (Depthwise  (None, 14, 12, 512)  4608       ['max_pooling2d_3[0][0]']
#  Conv2D)
#
#  batch_normalization_29 (BatchN  (None, 14, 12, 512)  2048       ['depthwise_conv2d_12[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 14, 12, 512)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 12, 1024  525312      ['re_lu_29[0][0]']
#                                 )
#
#  batch_normalization_30 (BatchN  (None, 14, 12, 1024  4096       ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  re_lu_30 (ReLU)                (None, 14, 12, 1024  0           ['batch_normalization_30[0][0]']
#                                 )
#
#  depthwise_conv2d_13 (Depthwise  (None, 14, 12, 1024  9216       ['re_lu_30[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_31 (BatchN  (None, 14, 12, 1024  4096       ['depthwise_conv2d_13[0][0]']
#  ormalization)                  )
#
#  re_lu_31 (ReLU)                (None, 14, 12, 1024  0           ['batch_normalization_31[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 14, 12, 1024  1049600     ['re_lu_31[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 14, 12, 1024  4096       ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  re_lu_32 (ReLU)                (None, 14, 12, 1024  0           ['batch_normalization_32[0][0]']
#                                 )
#
#  depthwise_conv2d_14 (Depthwise  (None, 14, 12, 1024  9216       ['re_lu_32[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_33 (BatchN  (None, 14, 12, 1024  4096       ['depthwise_conv2d_14[0][0]']
#  ormalization)                  )
#
#  re_lu_33 (ReLU)                (None, 14, 12, 1024  0           ['batch_normalization_33[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 14, 12, 1024  1049600     ['re_lu_33[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 14, 12, 1024  525312      ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 14, 12, 1024  4096       ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  batch_normalization_28 (BatchN  (None, 14, 12, 1024  4096       ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  re_lu_34 (ReLU)                (None, 14, 12, 1024  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  re_lu_28 (ReLU)                (None, 14, 12, 1024  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 14, 12, 1024  0           ['re_lu_34[0][0]',
#                                 )                                 're_lu_28[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 12, 128)  1179776     ['add_4[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 14, 12, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 14, 12, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 12, 64)   8192        ['re_lu_35[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 12, 64)   8192        ['re_lu_35[0][0]']
#
#  reshape (Reshape)              (None, 168, 64)      0           ['conv2d_21[0][0]']
#
#  reshape_1 (Reshape)            (None, 168, 64)      0           ['conv2d_22[0][0]']
#
#  dot (Dot)                      (None, 168, 168)     0           ['reshape[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 12, 64)   8192        ['re_lu_35[0][0]']
#
#  lambda (Lambda)                (None, 168, 168)     0           ['dot[0][0]']
#
#  reshape_2 (Reshape)            (None, 168, 64)      0           ['conv2d_23[0][0]']
#
#  dot_1 (Dot)                    (None, 168, 64)      0           ['lambda[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  reshape_3 (Reshape)            (None, 14, 12, 64)   0           ['dot_1[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 12, 128)  8192        ['reshape_3[0][0]']
#
#  add_5 (Add)                    (None, 14, 12, 128)  0           ['re_lu_35[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 12, 1024  1180672     ['add_5[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 14, 12, 1024  4096       ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  re_lu_36 (ReLU)                (None, 14, 12, 1024  0           ['batch_normalization_36[0][0]']
#                                 )
#
#  add_6 (Add)                    (None, 14, 12, 1024  0           ['re_lu_36[0][0]',
#                                 )                                 'add_4[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 28, 24, 1024  0           ['add_6[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 28, 24, 512)  4719104     ['up_sampling2d[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_26[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_37[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 24, 1024  0           ['add_3[0][0]',
#                                 )                                 're_lu_37[0][0]']
#
#  depthwise_conv2d_15 (Depthwise  (None, 28, 24, 1024  9216       ['concatenate[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_39 (BatchN  (None, 28, 24, 1024  4096       ['depthwise_conv2d_15[0][0]']
#  ormalization)                  )
#
#  re_lu_39 (ReLU)                (None, 28, 24, 1024  0           ['batch_normalization_39[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 28, 24, 512)  524800      ['re_lu_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_28[0][0]']
#  ormalization)
#
#  re_lu_40 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_40[0][0]']
#
#  depthwise_conv2d_16 (Depthwise  (None, 28, 24, 512)  4608       ['re_lu_40[0][0]']
#  Conv2D)
#
#  batch_normalization_41 (BatchN  (None, 28, 24, 512)  2048       ['depthwise_conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_41 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 28, 24, 512)  262656      ['re_lu_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_29[0][0]']
#  ormalization)
#
#  re_lu_42 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_42[0][0]']
#
#  depthwise_conv2d_17 (Depthwise  (None, 28, 24, 512)  4608       ['re_lu_42[0][0]']
#  Conv2D)
#
#  batch_normalization_43 (BatchN  (None, 28, 24, 512)  2048       ['depthwise_conv2d_17[0][0]']
#  ormalization)
#
#  re_lu_43 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 28, 24, 512)  262656      ['re_lu_43[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 28, 24, 512)  524800      ['concatenate[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 28, 24, 512)  2048       ['conv2d_27[0][0]']
#  ormalization)
#
#  re_lu_44 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_44[0][0]']
#
#  re_lu_38 (ReLU)                (None, 28, 24, 512)  0           ['batch_normalization_38[0][0]']
#
#  add_7 (Add)                    (None, 28, 24, 512)  0           ['re_lu_44[0][0]',
#                                                                   're_lu_38[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 56, 48, 512)  0          ['add_7[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 56, 48, 256)  1179904     ['up_sampling2d_1[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  re_lu_45 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_45[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 48, 512)  0           ['add_2[0][0]',
#                                                                   're_lu_45[0][0]']
#
#  depthwise_conv2d_18 (Depthwise  (None, 56, 48, 512)  4608       ['concatenate_1[0][0]']
#  Conv2D)
#
#  batch_normalization_47 (BatchN  (None, 56, 48, 512)  2048       ['depthwise_conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_47 (ReLU)                (None, 56, 48, 512)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 56, 48, 256)  131328      ['re_lu_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_33[0][0]']
#  ormalization)
#
#  re_lu_48 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_48[0][0]']
#
#  depthwise_conv2d_19 (Depthwise  (None, 56, 48, 256)  2304       ['re_lu_48[0][0]']
#  Conv2D)
#
#  batch_normalization_49 (BatchN  (None, 56, 48, 256)  1024       ['depthwise_conv2d_19[0][0]']
#  ormalization)
#
#  re_lu_49 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 56, 48, 256)  65792       ['re_lu_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 56, 48, 256)  1024       ['conv2d_34[0][0]']
#  ormalization)
#
#  re_lu_50 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_50[0][0]']
#
#  depthwise_conv2d_20 (Depthwise  (None, 56, 48, 256)  2304       ['re_lu_50[0][0]']
#  Conv2D)
#
#  batch_normalization_51 (BatchN  (None, 56, 48, 256)  1024       ['depthwise_conv2d_20[0][0]']
#  ormalization)
#
#  re_lu_51 (ReLU)                (None, 56, 48, 256)  0           ['batch_normalization_51[0][0]']
# ...
#
#  re_lu_53 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_53[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 112, 96, 256  0           ['add_1[0][0]',
#                                 )                                 're_lu_53[0][0]']
#
#  depthwise_conv2d_21 (Depthwise  (None, 112, 96, 256  2304       ['concatenate_2[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_55 (BatchN  (None, 112, 96, 256  1024       ['depthwise_conv2d_21[0][0]']
#  ormalization)                  )
#
#  re_lu_55 (ReLU)                (None, 112, 96, 256  0           ['batch_normalization_55[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 112, 96, 128  32896       ['re_lu_55[0][0]']
#                                 )
#
#  batch_normalization_56 (BatchN  (None, 112, 96, 128  512        ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  re_lu_56 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_56[0][0]']
#                                 )
#
#  depthwise_conv2d_22 (Depthwise  (None, 112, 96, 128  1152       ['re_lu_56[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_57 (BatchN  (None, 112, 96, 128  512        ['depthwise_conv2d_22[0][0]']
#  ormalization)                  )
#
#  re_lu_57 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_57[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 112, 96, 128  16512       ['re_lu_57[0][0]']
#                                 )
#
#  batch_normalization_58 (BatchN  (None, 112, 96, 128  512        ['conv2d_39[0][0]']
#  ormalization)                  )
#
#  re_lu_58 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_58[0][0]']
#                                 )
#
#  depthwise_conv2d_23 (Depthwise  (None, 112, 96, 128  1152       ['re_lu_58[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_59 (BatchN  (None, 112, 96, 128  512        ['depthwise_conv2d_23[0][0]']
#  ormalization)                  )
#
#  re_lu_59 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_59[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 112, 96, 128  16512       ['re_lu_59[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 112, 96, 128  32896       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_60 (BatchN  (None, 112, 96, 128  512        ['conv2d_40[0][0]']
#  ormalization)                  )
#
#  batch_normalization_54 (BatchN  (None, 112, 96, 128  512        ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  re_lu_60 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_60[0][0]']
#                                 )
#
#  re_lu_54 (ReLU)                (None, 112, 96, 128  0           ['batch_normalization_54[0][0]']
#                                 )
#
#  add_9 (Add)                    (None, 112, 96, 128  0           ['re_lu_60[0][0]',
#                                 )                                 're_lu_54[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 224, 192, 12  0          ['add_9[0][0]']
#                                 8)
#
#  conv2d_41 (Conv2D)             (None, 224, 192, 64  73792       ['up_sampling2d_3[0][0]']
#                                 )
#
#  batch_normalization_61 (BatchN  (None, 224, 192, 64  256        ['conv2d_41[0][0]']
#  ormalization)                  )
#
#  re_lu_61 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_61[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 224, 192, 12  0           ['add[0][0]',
#                                 8)                                're_lu_61[0][0]']
#
#  depthwise_conv2d_24 (Depthwise  (None, 224, 192, 12  1152       ['concatenate_3[0][0]']
#  Conv2D)                        8)
#
#  batch_normalization_63 (BatchN  (None, 224, 192, 12  512        ['depthwise_conv2d_24[0][0]']
#  ormalization)                  8)
#
#  re_lu_63 (ReLU)                (None, 224, 192, 12  0           ['batch_normalization_63[0][0]']
#                                 8)
#
#  conv2d_43 (Conv2D)             (None, 224, 192, 64  8256        ['re_lu_63[0][0]']
#                                 )
#
#  batch_normalization_64 (BatchN  (None, 224, 192, 64  256        ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  re_lu_64 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_64[0][0]']
#                                 )
#
#  depthwise_conv2d_25 (Depthwise  (None, 224, 192, 64  576        ['re_lu_64[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_65 (BatchN  (None, 224, 192, 64  256        ['depthwise_conv2d_25[0][0]']
#  ormalization)                  )
#
#  re_lu_65 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_65[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 224, 192, 64  4160        ['re_lu_65[0][0]']
#                                 )
#
#  batch_normalization_66 (BatchN  (None, 224, 192, 64  256        ['conv2d_44[0][0]']
#  ormalization)                  )
#
#  re_lu_66 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_66[0][0]']
#                                 )
#
#  depthwise_conv2d_26 (Depthwise  (None, 224, 192, 64  576        ['re_lu_66[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_67 (BatchN  (None, 224, 192, 64  256        ['depthwise_conv2d_26[0][0]']
#  ormalization)                  )
#
#  re_lu_67 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_67[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 224, 192, 64  4160        ['re_lu_67[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 224, 192, 64  8256        ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_68 (BatchN  (None, 224, 192, 64  256        ['conv2d_45[0][0]']
#  ormalization)                  )
#
#  batch_normalization_62 (BatchN  (None, 224, 192, 64  256        ['conv2d_42[0][0]']
#  ormalization)                  )
#
#  re_lu_68 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_68[0][0]']
#                                 )
#
#  re_lu_62 (ReLU)                (None, 224, 192, 64  0           ['batch_normalization_62[0][0]']
#                                 )
#
#  add_10 (Add)                   (None, 224, 192, 64  0           ['re_lu_68[0][0]',
#                                 )                                 're_lu_62[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 224, 192, 1)  65          ['add_10[0][0]']
#
# ==================================================================================================
# Total params: 15,117,646
# Trainable params: 15,072,332
# Non-trainable params: 45,314
# __________________________________________________________________________________________________
# Create X-Net with N block, input shape = (224, 192, 1), output shape = (None, 224, 192, 1)
# 9828
#    2/1228 [..............................] - ETA: 22:35:12 - loss: 1.6948 - dice: 0.0142
